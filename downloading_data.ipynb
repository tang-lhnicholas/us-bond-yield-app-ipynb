# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import os
import time

currentyear = datetime.now().year
lastyear = currentyear - 1
datetoday = datetime.today().strftime('%B-%d-%Y')
def downloaddata(startyear, endyear):
    data_list = []
    print('Downloading data. This should take less than a minute.')
    for year in range(startyear, endyear+1):
        url = f'https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value={str(year)}'
        
        # Send a GET request to the URL
        start = time.time()
        response = requests.get(url)
        end = time.time()
        print(f'Request success. Time: {round(end - start, 3)}s')
        if response.status_code == 200:
            start=time.time()
            soup = BeautifulSoup(response.content, 'html.parser')
    
            # Find the table containing the data
            table = soup.find('table', class_='views-table')
    
            rows = table.find_all('tr')
    
            for row in rows[1:]:  # Skip the first row as it contains headers
                # Extract table data from each row
                data = [cell.get_text(strip=True) for cell in row.find_all(['td', 'th'])]
                data_dict = {
                    'Date': data[0],
                    '1 Mo': data[10],
                    '2 Mo': data[11],
                    '3 Mo': data[12],
                    '6 Mo': data[13],
                    '1 Yr': data[14],
                    '2 Yr': data[15],
                    '3 Yr': data[16],
                    '5 Yr': data[17],
                    '7 Yr': data[18],
                    '10 Yr': data[19],
                    '20 Yr': data[20],
                    '30 Yr': data[21]
                }
                data_list.append(data_dict)
            end = time.time()
            print(f'Parsing complete. Time: {round(end - start, 3)}s')
    # Create a DataFrame from the list of dictionaries
    df = pd.DataFrame(data_list)
    return df


# Download data from 1990 to last year if data is not already local
if os.path.isfile(f'./Data/US Bond Yield Data from 1990-{lastyear}.csv') == True:
    pass

else:
    downloaddata(1990, lastyear).to_csv(f'Data/US Bond Yield Data from 1990-{lastyear}.csv', index=False)  

# Download data of most recent year if not done on the day

with open('Data/Last download date log.txt', 'r') as file:
    date = file.read()
    if date != str(datetoday) or os.path.isfile(f'./Data/US Bond Yield Data YTD {currentyear}.csv') == False:
        
        if os.path.isfile(f'./Data/US Bond Yield Data YTD {currentyear}.csv') == True: 
            os.remove(f'./Data/US Bond Yield Data YTD {currentyear}.csv')
            
        downloaddata(currentyear, currentyear).to_csv(f'Data/US Bond Yield Data YTD {currentyear}.csv', index=False)  
    
        # Merge the two files
        df1 = pd.read_csv(f'Data/US Bond Yield Data from 1990-{lastyear}.csv')
        df2 = pd.read_csv(f'Data/US Bond Yield Data YTD {currentyear}.csv')
        merged_df = pd.concat([df1, df2], ignore_index=True)
        
        if os.path.isfile(f'./Data/_US Bond Yield Data from 1990 to date.csv') == True: 
            os.remove(f'./Data/_US Bond Yield Data from 1990 to date.csv')
        merged_df.to_csv(f'Data/_US Bond Yield Data from 1990 to date.csv', index=False)
        open('Data/Last download date log.txt', 'w').write(str(datetoday))
        print(f'Data last updated: {datetoday}')
# Out:
# Downloading data. This should take less than a minute.
# Request success. Time: (10.64218807220459, 3)s
# Parsing complete. Time: 0.14421987533569336s
# Parsing complete. Time: 0.14430904388427734s
# Parsing complete. Time: 0.14438199996948242s
# Parsing complete. Time: 0.1444540023803711s
# Parsing complete. Time: 0.14452385902404785s
# Parsing complete. Time: 0.1445939540863037s
# Parsing complete. Time: 0.14466381072998047s
# Parsing complete. Time: 0.14473390579223633s
# Parsing complete. Time: 0.1448040008544922s
# Parsing complete. Time: 0.14487409591674805s
# Parsing complete. Time: 0.1449439525604248s
# Parsing complete. Time: 0.14501476287841797s
# Parsing complete. Time: 0.14508605003356934s
# Parsing complete. Time: 0.1451559066772461s
# Parsing complete. Time: 0.14522600173950195s
# Parsing complete. Time: 0.1452958583831787s
# Parsing complete. Time: 0.14536571502685547s
# Parsing complete. Time: 0.14543485641479492s
# Parsing complete. Time: 0.14550471305847168s
# Parsing complete. Time: 0.14557504653930664s
# Parsing complete. Time: 0.14564800262451172s
# Parsing complete. Time: 0.1457228660583496s
# Parsing complete. Time: 0.14579391479492188s
# Parsing complete. Time: 0.14586400985717773s
# Parsing complete. Time: 0.1459338665008545s
# Parsing complete. Time: 0.14600396156311035s
# Parsing complete. Time: 0.1460738182067871s
# Parsing complete. Time: 0.14614415168762207s
# Parsing complete. Time: 0.14621591567993164s
# Parsing complete. Time: 0.1462857723236084s
# Parsing complete. Time: 0.14635610580444336s
# Parsing complete. Time: 0.14642691612243652s
# Parsing complete. Time: 0.14649605751037598s
# Parsing complete. Time: 0.14656591415405273s
# Parsing complete. Time: 0.1466350555419922s
# Parsing complete. Time: 0.14670491218566895s
# Parsing complete. Time: 0.1467738151550293s
# Parsing complete. Time: 0.14684391021728516s
# Parsing complete. Time: 0.14691376686096191s
# Parsing complete. Time: 0.14698505401611328s
# Parsing complete. Time: 0.14705705642700195s
# Parsing complete. Time: 0.1471269130706787s
# Parsing complete. Time: 0.14719700813293457s
# Parsing complete. Time: 0.14726686477661133s
# Parsing complete. Time: 0.1473369598388672s
# Parsing complete. Time: 0.14740681648254395s
# Parsing complete. Time: 0.1474759578704834s
# Parsing complete. Time: 0.14754581451416016s
# Parsing complete. Time: 0.1476149559020996s
# Parsing complete. Time: 0.14768481254577637s
# Parsing complete. Time: 0.14775395393371582s
# Parsing complete. Time: 0.14782381057739258s
# Parsing complete. Time: 0.14789295196533203s
# Parsing complete. Time: 0.1479630470275879s
# Parsing complete. Time: 0.14803194999694824s
# Parsing complete. Time: 0.1481008529663086s
# Parsing complete. Time: 0.14816999435424805s
# Parsing complete. Time: 0.1482398509979248s
# Parsing complete. Time: 0.14830970764160156s
# Parsing complete. Time: 0.14837884902954102s
# Parsing complete. Time: 0.1484529972076416s
# Parsing complete. Time: 0.14852213859558105s
# Parsing complete. Time: 0.1485908031463623s
# Parsing complete. Time: 0.14865994453430176s
# Parsing complete. Time: 0.14872980117797852s
# Parsing complete. Time: 0.1488039493560791s
# Parsing complete. Time: 0.14887404441833496s
# Parsing complete. Time: 0.14894390106201172s
# Parsing complete. Time: 0.14901375770568848s
# Parsing complete. Time: 0.14908289909362793s
# Parsing complete. Time: 0.1491527557373047s
# Parsing complete. Time: 0.14922189712524414s
# Parsing complete. Time: 0.1492908000946045s
# Parsing complete. Time: 0.14936089515686035s
# Parsing complete. Time: 0.1494297981262207s
# Parsing complete. Time: 0.14949893951416016s
# Parsing complete. Time: 0.1495680809020996s
# Parsing complete. Time: 0.14963793754577637s
# Parsing complete. Time: 0.14970707893371582s
# Parsing complete. Time: 0.14977598190307617s
# Parsing complete. Time: 0.14984512329101562s
# Parsing complete. Time: 0.14991402626037598s
# Parsing complete. Time: 0.14998292922973633s
# Parsing complete. Time: 0.15005183219909668s
# Parsing complete. Time: 0.15012788772583008s
# Parsing complete. Time: 0.15019989013671875s
# Parsing complete. Time: 0.1502690315246582s
# Parsing complete. Time: 0.15033888816833496s
# Parsing complete. Time: 0.15040802955627441s
# Parsing complete. Time: 0.15047788619995117s
# Parsing complete. Time: 0.15054702758789062s
# Parsing complete. Time: 0.15061593055725098s
# Parsing complete. Time: 0.15068507194519043s
# Parsing complete. Time: 0.1507549285888672s
# Parsing complete. Time: 0.15082502365112305s
# Parsing complete. Time: 0.1508939266204834s
# Parsing complete. Time: 0.15096402168273926s
# Parsing complete. Time: 0.15103387832641602s
# Parsing complete. Time: 0.15110397338867188s
# Parsing complete. Time: 0.15117692947387695s
# Parsing complete. Time: 0.15124797821044922s
# Parsing complete. Time: 0.15131783485412598s
# Parsing complete. Time: 0.15138697624206543s
# Parsing complete. Time: 0.15145611763000488s
# Parsing complete. Time: 0.15152907371520996s
# Parsing complete. Time: 0.15159893035888672s
# Parsing complete. Time: 0.15166807174682617s
# Parsing complete. Time: 0.15173792839050293s
# Parsing complete. Time: 0.15180706977844238s
# Parsing complete. Time: 0.15187597274780273s
# Parsing complete. Time: 0.151947021484375s
# Parsing complete. Time: 0.15201592445373535s
# Parsing complete. Time: 0.1520850658416748s
# Parsing complete. Time: 0.15215492248535156s
# Parsing complete. Time: 0.15222406387329102s
# Parsing complete. Time: 0.15229296684265137s
# Parsing complete. Time: 0.15236377716064453s
# Parsing complete. Time: 0.1524338722229004s
# Parsing complete. Time: 0.15250277519226074s
# Parsing complete. Time: 0.1525728702545166s
# Parsing complete. Time: 0.15264177322387695s
# Parsing complete. Time: 0.1527109146118164s
# Parsing complete. Time: 0.15278077125549316s
# Parsing complete. Time: 0.15284991264343262s
# Parsing complete. Time: 0.15292096138000488s
# Parsing complete. Time: 0.15299201011657715s
# Parsing complete. Time: 0.1530609130859375s
# Parsing complete. Time: 0.15313172340393066s
# Parsing complete. Time: 0.15320205688476562s
# Parsing complete. Time: 0.15327072143554688s
# Parsing complete. Time: 0.15334200859069824s
# Parsing complete. Time: 0.1534109115600586s
# Parsing complete. Time: 0.15348100662231445s
# Parsing complete. Time: 0.1535508632659912s
# Parsing complete. Time: 0.15362000465393066s
# Parsing complete. Time: 0.15369296073913574s
# Parsing complete. Time: 0.1537618637084961s
# Parsing complete. Time: 0.15383100509643555s
# Parsing complete. Time: 0.1538999080657959s
# Parsing complete. Time: 0.15396904945373535s
# Parsing complete. Time: 0.15404486656188965s
# Parsing complete. Time: 0.15411376953125s
# Parsing complete. Time: 0.15418291091918945s
# Parsing complete. Time: 0.1542527675628662s
# Parsing complete. Time: 0.15432310104370117s
# Parsing complete. Time: 0.15439295768737793s
# Parsing complete. Time: 0.15446209907531738s
# Parsing complete. Time: 0.15453386306762695s
# Parsing complete. Time: 0.15460491180419922s
# Parsing complete. Time: 0.1546788215637207s
# Parsing complete. Time: 0.15475010871887207s
# Parsing complete. Time: 0.15481996536254883s
# Parsing complete. Time: 0.1548900604248047s
# Parsing complete. Time: 0.15496087074279785s
# Parsing complete. Time: 0.1550297737121582s
# Parsing complete. Time: 0.15510296821594238s
# Parsing complete. Time: 0.15517187118530273s
# Parsing complete. Time: 0.1552410125732422s
# Parsing complete. Time: 0.15531086921691895s
# Parsing complete. Time: 0.1553800106048584s
# Parsing complete. Time: 0.15544986724853516s
# Parsing complete. Time: 0.15551996231079102s
# Parsing complete. Time: 0.15558886528015137s
# Parsing complete. Time: 0.15565896034240723s
# Parsing complete. Time: 0.15572786331176758s
# Parsing complete. Time: 0.15579771995544434s
# Parsing complete. Time: 0.1558668613433838s
# Parsing complete. Time: 0.15593600273132324s
# Parsing complete. Time: 0.156005859375s
# Parsing complete. Time: 0.15607571601867676s
# Parsing complete. Time: 0.15614604949951172s
# Data last updated: September-06-2024
